# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler
import random
import time

TOPIC = "canzoni"
SERVER = 'localhost:9092'

# Inizializzare SparkSession
spark = SparkSession \
        .builder \
        .appName("Emergify Recomendation System") \
        .master("local[*]") \
        .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

#Spark Streaming
df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", SERVER) \
        .option("subscribe", TOPIC) \
        .option("startingOffsets", "latest") \
        .load()

df1 = df.selectExpr("CAST(value AS STRING)", "timestamp") 

def_schema = "order_id INT, id STRING, name STRING, popularity INT, duration_ms DOUBLE, " \
             + "artists STRING, id_artists STRING, release_date STRING, " \
             + "danceability DOUBLE,energy DOUBLE, key INT, loudness DOUBLE, " \
             + "mode INT,speechiness DOUBLE," \
             + "acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, " \
             + "valence DOUBLE, tempo DOUBLE, time_signature DOUBLE"
df2 = df1.select(from_csv(col("value"),def_schema).alias("song"), "timestamp")

# %%
#Creare View 
df3 = df2.select("song.*", "timestamp")  
df3.createOrReplaceTempView("df3_View");
df3.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- duration_ms: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- id_artists: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- acousticness: double (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- time_signature: double (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
song_find = spark.sql("SELECT * FROM df3_View")

#Write in memoria
songs_write = song_find \
        .writeStream \
        .trigger(processingTime='5 seconds') \
        .outputMode("append") \
        .option("truncate", "false") \
        .format("memory") \
        .queryName("Table7") \
        .start()

songs_write.awaitTermination(1)
# Out:
# False

# %%
spark_songs = spark.sql("SELECT * FROM Table7")
#spark_songs.show()
spark_songs.select('order_id','id','name','popularity','duration_ms','artists').show(3)
# Out:
# +--------+--------------------+---------+----------+-----------+--------------------+
# |order_id|                  id|     name|popularity|duration_ms|             artists|
# +--------+--------------------+---------+----------+-----------+--------------------+
# |      38|5kRJFL34WexICZFj5...|Limitless|         1|   177005.0|AuroraAnthonyLoui...|
# |      39|1h5nhUpNi7naqZIdb...|   No Cap|         1|   184634.0|              XoSuav|
# |      40|31ezfRnEbz4QjTZsv...| Big Tyme|         0|   225903.0|  CZARnicholasSahara|
# +--------+--------------------+---------+----------+-----------+--------------------+
# only showing top 3 rows

# %%
spark_songs.count()
# Out:
# 95

# %%
#SPOTIFY API

import spotipy
import spotipy.util
import seaborn as sns
import pandas as pd
import os
import numpy as np
import pandas as pd
import ujson


os.environ["SPOTIPY_CLIENT_ID"] = '06e71ff0e72e43a686c928e968376472'
os.environ["SPOTIPY_CLIENT_SECRET"] = '8b9f20e887de4b4baa4f3a35748d0c34'
os.environ["SPOTIPY_REDIRECT_URI"] = 'http://localhost:7777/callback'


scope = 'user-library-read'
username = 'iNSERIRE USERNAME'

token = spotipy.util.prompt_for_user_token(username, scope)
spotipy_obj = spotipy.Spotify(auth=token)
saved_tracks = spotipy_obj.current_user_saved_tracks(limit=50) 
n_tracks = saved_tracks['total']
print('Totale canzoni: %d ' % n_tracks)
# Out:
# Totale canzoni: 923

# %%
def select_features(track_response):
    return {        
        'id': str(track_response['track']['id']),
        'name': str(track_response['track']['name']),
        'artists': [artist['name'] for artist in track_response['track']['artists']],
        'popularity': track_response['track']['popularity']
    }

tracks = [select_features(track) for track in saved_tracks['items']]

while saved_tracks['next']:
    saved_tracks = spotipy_obj.next(saved_tracks)
    tracks.extend([select_features(track) for track in saved_tracks['items']])

#Creare dataframe in pandas
tracks_df = pd.DataFrame(tracks)
pd.set_option('display.max_rows', len(tracks))
tracks_df['artists'] = tracks_df['artists'].apply(lambda artists: artists[0])

# %%
#Aggiungere audio features
audio_features = {}

for idd in tracks_df['id'].tolist():
    audio_features[idd] = spotipy_obj.audio_features(idd)[0]
    
tracks_df['acousticness'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['acousticness'])
tracks_df['speechiness'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['speechiness'])
tracks_df['key'] = tracks_df['id'].apply(lambda idd: str(audio_features[idd]['key']))
tracks_df['liveness'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['liveness'])
tracks_df['instrumentalness'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['instrumentalness'])
tracks_df['energy'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['energy'])
tracks_df['tempo'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['tempo'])
tracks_df['loudness'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['loudness'])
tracks_df['danceability'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['danceability'])
tracks_df['valence'] = tracks_df['id'].apply(lambda idd: audio_features[idd]['valence'])

tracks_df
# Out:
#                          id  \
# 0    3nOz1U41SZZ0N3fuUWr9nb
# 1    5Qnrgqy1pAm9GyNQOgyVFz
# 2    2y1UG6Ps1h6rgKYW9kk6bC
# 3    7GLSAyJY25FyB7w0blIdDf
# 4    36V4aP2bpDUuvBYcpku9LI
# 5    5gVMHBodcPKPvFTxnFV5BT
# 6    1175r6ZmkUjX8dRJLz9Ohk
# 7    1Dp7ASSZVVOPJ85VdLpjOX
# 8    6lAMnXLVCBPMXXWAK4lGSL
# 9    1AC9rHDPQC3QoC3iYPeSEI
# 10   0CSMtmcfcDJ00FxaHLuMQL
# 11   1VGzxJnVQND7Cg5H5wGj14
# 12   4k7x3QKrc3h3U0Viqk0uop
# 906  2tuCQN6ldg4ntnz8tNKjV8
# 907  7ctRAoCbcpOusbm3w3E6mn
# 908  2a8pQLSuhloP8ywoy5Or5i
# 909  2OuNgtXKeCSORKqdl0MxKk
# 910  4yzgjSHWy5E8fKflgwaKQh
# 911  4UnbdQoTvXhiKpPCBgW8Tn
# 912  48psxWnIVYCPUZJKiuDiEf
# 913  2f3pT7xCMaNUL3jWNZDSto
# 914  6OaCwySGYg30ncfsjKNbtM
# 915  7AUwhTIuxBn7Os76FPoIz7
# 916  6QHIhlLTb02tvEPtZZtXXw
# 917  53rVYwGiKUC3gYX8SQQYYU
# 918  5zYoaHjRlIEAK2jJJzHkmO
# 919  4L0CZr4WM32ymqvAsUoeeS
# 920  3aKJVWH2QOsaMtiCLxYHZX
# 921  2S4lAby9LtHrSS8l5kyHO9
# 922  6HJujxcjMmVZhd8z5EpPri
#
#                                                   name  \
# 0                                           I AM WOMAN
# 1                                       Fourth of July
# 2                                            Treehouse
# 3                              IL MIO CUORE È OCCUPATO
# 4                                     Pure Imagination
# 5                        Aging out of the 20th Century
# 6                                        I Love You So
# 7                                Seventeen Going Under
# 8                                          Ylang Ylang
# 9                                     Quanto ti vorrei
# 10                     Feels Like We Only Go Backwards
# 11                                          YEAH RIGHT
# 12                                              Rosyln
# 13                                       Big Black Car
# 14                                            Godspeed
# 15                                      rises the moon
# 16                           It's Not The Same Anymore
# 17                                             Whisper
# 18                                           papercuts
# 19                                          Heat Waves
# 20                                         Lovers Rock
# 21                                         Possibility
# 22                                              august
# 23                                       Electric Love
# 24                                             Colapso
# 25                                   Happier Than Ever
# 26                            Je te laisserai des mots
# 27                                      favorite crime
# 28                     How Can You Mend a Broken Heart
# 29                                              Estate
# 30                                       De Mi Para Ti
# 31                                     drivers license
# 32                              idontwannabeyouanymore
# 33                                            GABBIANO
# 34                                           Bluetooth
# 35                                        Oh Satellity
# 36                                 E TE VENG' A PIGLIÀ
# 37                                       In Luv With U
# 38                                              Regina
# 39                               when the party's over
# 40                                         Without You
# 41                              The Adults Are Talking
# 42                                             Runaway
# 43                     What falling in love feels like
# 44                                   In My Little Mind
# 45                                      La Vie En Rose
# 46                                  Fiamme negli occhi
# 47                                     Santa Marinella
# 48                     Lo Vas A Olvidar (with ROSALÍA)
# 49                                           Liability
# 50                 Where's My Love - Alternate Version
# 51                                              Berlin
# 52                                                 Lua
# 53                                         Reflections
# 54                                       White Ferrari
# 55                        Song on the Beach/Photograph
# 56                         If I Fell - Remastered 2009
# 57                                                Home
# 58                                               Renee
# 59                            Still Don't Know My Name
# 60                                  you broke me first
# 61                          Lonely (with benny blanco)
# 62                          i think you're really cool
# 63      You Are Everything And I Am Nothing... (bonus)
# 64                                          Shark Week
# 65   make you mine (Massimo Pericolo Remix) feat. S...
# 66                         Goodbyes (Feat. Young Thug)
# 67                    Falling in Love at a Coffee Shop
# 68                         I Met Sarah in the Bathroom
# 69                                        I Fall Apart
# 70                                              Rewind
# 71                         How To Never Stop Being Sad
# 72                                             Matilda
# 73                                          Douchebags
# 74                            I Hate That You're Happy
# 75                                         Best Friend
# 76                                  Things That I Miss
# 77                    Cupid De Locke - Remastered 2012
# 78                                    The Last Goodbye
# 79                              Ora che ti guardo bene
# 80                                    Chinese New Year
# 81                                           Carry You
# 82                                                Only
# 83                                               Clara
# 84                                            Medicine
# 85                                        Backyard Boy
# 86                                              TOMBOY
# 87                                           my future
# 88                             for lovers who hesitate
# 89                                          In Silence
# 90                                              Chanel
# 91         Bust Your Knee Caps - Johnny Don't Leave Me
# 92                                   Le cose sbagliate
# 93                                             Amarena
# 94                                            Contento
# 95                                      Buio di giorno
# 96                                                 Lee
# 97                                               Klimt
# 98                               Make You Feel My Love
# 99                                   Ti sorprenderebbe
# 100                                  Come Quella Volta
# 101                        Not How It's Supposed To Go
# 102                               Per due che come noi
# 103                                        Paracetamol
# 104                                      Make You Mine
# 105                                             Lonely
# 106                         16 Marzo (feat. Gow Tribe)
# 107  LE RAGAZZE DI PORTA VENEZIA - THE MANIFESTO (f...
# 108                                 Drunk Text Romance
# 109                                           Pensione
# 110               O CORE NUN TENE PADRONE - APACHE MIX
# 111                                         Settebello
# 112                                          In Dreams
# 113                                    Nei giorni così
# 114                                 Moral of the Story
# 115                                 Giudizi universali
# 116                                WE COME FROM NAPOLI
# 117                                            Curlews
# 118                                        Tallahassee
# 119                                              Blend
# 120                                           Should I
# 121                                       Sesame Syrup
# 122                Non Succederà Più (feat. M¥SS KETA)
# 123                               You Are The Only One
# 124                                         Fai rumore
# 125                                            Bergamo
# 126                                             Ridere
# 127                                 CRUDELIA - I nervi
# 128                                             Estate
# 129                                                Sei
# 130                             Il cielo in una stanza
# 131                               Dragon Ball Giuro Ti
# 132                              Non Me Lo So Spiegare
# 133                    MADAME - L'anima (feat. Madame)
# 134                                             Giugno
# 135                                          ATTO ZERO
# 136                             Dove Non Batte Il Sole
# 137                                          Slow Song
# 138                                           Yoko Ono
# 139                                     Safe and Sound
# 140                              Non Ti Prendo La Mano
# 141                                            America
# 142                                Una casa sulla luna
# 143                              Maschi contro femmine
# 144                                            GRANATA
# 145                            Chocolates & Cigarettes
# 146                                 Death with Dignity
# 147                 Dancin (feat. Luvli) - Krono Remix
# 148                                     Tra Le Giostre
# 149                                      Cercasi Amore
# 150                                  Al Giusto Momento
# 151  L'amore ai tempi dei licenziamenti dei metalme...
# 152                                         Next To Me
# 153                                            Je veux
# 154                                      Don't Miss It
# 155                                        Consequence
# 156                                          Wild Eyed
# 157                                         i love you
# 158                                   Chinese New Year
# 159                                 When Have I Fallen
# 160                                          Lights Up
# 161                                   LA DOCCIA DEL 25
# 162  Satie / Arr. Barker & Balsom: 3 Gymnopédies: N...
# 163                                   Between The Bars
# 164                                      Tararì Tararà
# 165                                           Farmacia
# 166                                       Questa Notte
# 167                                    Se tu non torni
# 168                                          New Slang
# 169                                        Don't Panic
# 170                                   Yes I'm Changing
# 171                               LA MIA ULTIMA STORIA
# 172                                   A piedi il mondo
# 173                                     Los Días Raros
# 174                                        Fuori di me
# 175                                            Tommaso
# 176                                     La tua canzone
# 177                                     The reason why
# 178                                            Altrove
# 179                                         Conchiglie
# 180                              La vita e la felicità
# 181                                           Maremoto
# 182                                    Abbi cura di te
# 183                                   Colline Di Jeans
# 184                               UNA VITA IN CAPSLOCK
# 185                                UNA DONNA CHE CONTA
# 186                                            Ichnusa
# 187                                      The First Lie
# 188                                           Brioschi
# 189                                  Tappeti Del Bagno
# 190                                          Cattolica
# 191                                         Illuminate
# 192                                           Legoland
# 193                                             Chakra
# 194                                           ARSENICO
# 195                                              Cuore
# 196                                      In This Shirt
# 197                                          Porcelain
# 198                    Scusa (feat. Ugo Borghetti & B)
# 199                                       Dry the Rain
# 200                             Sorriso (Milano Dateo)
# 201                                          Due punti
# 202                                       White Nights
# 203                                       Breezeblocks
# 204                                            Deserto
# 205                                         Montesanto
# 206                          Dovremmo Prendere Un Cane
# 207  La Luna e la Gatta (feat. Tommaso Paradiso, Jo...
# 208                                          A LAMETTA
# 209                                    Lonely Feelings
# 210                                              Happy
# 211                              Narcotic - Radio Edit
# 212                             NUNN'A VOGLIO 'NCUNTRÀ
# 213                                             NIENTE
# 214                                           GUAGLIÒ
# 215                            ME STAJE APPENNENN' AMÒ
# 216                              TU ME FAJE ASCÌ PAZZ'
# 217                                            OI MARÌ
# 218                                             GAIOLA
# 219                                       Lucky Strike
# 220                                       C'est la vie
# 221                    I'm Your Sacrifice - Radio Edit
# 222                                         Moon River
# 223              IL CIELO NELLA STANZA (feat. NSTASIA)
# 224                                    Fuori dall'Hype
# 225                                     Song About You
# 226                                               Gulf
# 227               Mezzo Cocktail (feat. Ugo Borghetti)
# 228                                             Catene
# 229                                        Mal di gola
# 230                                           MANCARSI
# 231                                       Stolen Dance
# 232                                    Come Down to Us
# 233                                      bury a friend
# 234                                         Take on Me
# 235                           Pomezia + Amarena - Live
# 236                                           Comunque
# 237                                            Termini
# 238                                      L'impossibile
# 239                                   The Great Escape
# 240                                              Candy
# 241                                   Solo Una Canzone
# 242            Senza Di Me (feat. Venerus & Franco126)
# 243                         Island (queen of diamonds)
# 244                                           Sayonara
# 245                                          Meltinpot
# 246                                           Maionese
# 247                                The OA - Main Theme
# 248                                           Downtown
# 249                                           Solo3min
# 250                                     Nudo Integrale
# 251                                         Jugoslavia
# 252                                           Pakistan
# 253                                      Anima Lattina
# 254                          Gotta Get Up - Remastered
# 255                       Cherry Blossom (Moors Remix)
# 256                                      I Go to Sleep
# 257                                                 If
# 258                                     È sempre bello
# 259                                          Gli occhi
# 260                              L'estate sopra di noi
# 261                                       Come un cane
# 262                                         Promettimi
# 263                                            Bologna
# 264                                      Hai visto mai
# 265                                            Grecale
# 266                                   Le notti bianche
# 267                            La notte di San Lorenzo
# 268                                     Follia d'amore
# 269                                     Ambra era nuda
# 270                                             Sparks
# 271                             La lotta armata al bar
# 272                                         I Love You
# 273                                       Stressed Out
# 274                                           San Siro
# 275                                    Nuvole Di Drago
# 276                                       Fa Lo Stesso
# 277                                    Parole Crociate
# 278                                 La Musica Italiana
# 279                                Won't You Come Home
# 280                                               Feel
# 281                                            Verdura
# 282            Stanza Singola (feat. Tommaso Paradiso)
# 283                                           Over Now
# 284                                               Stay
# 285                       Psycho (feat. Ty Dolla $ign)
# 286                            Con i chilometri contro
# 287                                      Big Jet Plane
# 288                                    Ricomincio da 3
# 289                                  Sentimento estero
# 290                                                  V
# 291                              Colazione da gattullo
# 292                                          Le barche
# 293                                         Calabi-Yau
# 294                                    Mystery of Love
# 295                                 Don't Keep Driving
# 296                                 Way Back Into Love
# 297                                           Alla Tua
# 298                                           Dreamers
# 299                  La felicità non è una truffa 2018
# 300                                                Noi
# 301                                           Accuccia
# 302                                       Ieri L'Altro
# 303                             Costellazioni di Kebab
# 304                              Milano - Demo Version
# 305                                              Dateo
# 306                                             Stormi
# 307                                       Domenicamara
# 308             Se Piovesse Il Tuo Nome - con Calcutta
# 309                                            Vinavil
# 310                                                Rai
# 311                                            Sinmigo
# 312                                              Esami
# 313                                           Tubature
# 314                             Wasting My Young Years
# 315                                              Merci
# 316                                               Myth
# 317  Da sola / In the night (feat. Tommaso Paradiso...
# 318                                            Cazzate
# 319                        Ridere Di Noi (feat. Luchè)
# 320                           Amore ai tempi dell'Ikea
# 321                                            Shallow
# 322                                               Vita
# 323                                  La fine del mondo
# 324                                          Scintille
# 325                     Se piovesse il tuo nome - Live
# 326                                 La legge di Murphy
# 327                            Posso (feat. Max Gazzè)
# 328     La Cuenta (feat. Franco 126 & Federica Abbate)
# 329                                   Palazzina Gialla
# 330                                     Stelle filanti
# 331                                       Me and Terry
# ...
# 372         0.731   0.5880
# 373         0.575   0.3850
# 374         0.585   0.1290
# 375         0.590   0.6860
# 376         0.552   0.4350
# 377         0.674   0.2450
# 378         0.259   0.0689
# 379         0.567   0.6670
# 380         0.474   0.4110
# 381         0.615   0.2710
# 382         0.630   0.6670
# 383         0.658   0.8320
# 384         0.589   0.5200
# 385         0.516   0.2470
# 386         0.600   0.4910
# 387         0.744   0.7930
# 388         0.593   0.2550
# 389         0.753   0.7740
# 390         0.685   0.7570
# 391         0.602   0.6170
# 392         0.670   0.1460
# 393         0.502   0.1340
# 394         0.509   0.7630
# 395         0.574   0.3380
# 396         0.584   0.5650
# 397         0.725   0.8540
# 398         0.717   0.5270
# 399         0.706   0.6760
# 400         0.496   0.1580
# 401         0.441   0.4680
# 402         0.490   0.5780
# 403         0.587   0.1510
# 404         0.301   0.3360
# 405         0.461   0.1120
# 406         0.666   0.5310
# 407         0.634   0.3830
# 408         0.619   0.3390
# 409         0.649   0.3740
# 410         0.446   0.2510
# 411         0.565   0.1520
# 412         0.681   0.0953
# 413         0.777   0.8650
# 414         0.626   0.4700
# 415         0.566   0.2920
# 416         0.677   0.7300
# 417         0.375   0.3010
# 418         0.625   0.2460
# 419         0.729   0.3320
# 420         0.665   0.3100
# 421         0.696   0.2740
# 422         0.203   0.0342
# 423         0.523   0.1510
# 424         0.531   0.3360
# 425         0.526   0.5990
# 426         0.697   0.0720
# 427         0.457   0.5240
# 428         0.747   0.3310
# 429         0.370   0.1900
# 430         0.603   0.2160
# 431         0.347   0.3380
# 432         0.540   0.3470
# 433         0.372   0.2110
# 434         0.463   0.3740
# 435         0.559   0.3990
# 436         0.427   0.2980
# 437         0.630   0.3800
# 438         0.677   0.1930
# 439         0.575   0.5430
# 440         0.670   0.0709
# 441         0.581   0.1380
# 442         0.781   0.8900
# 443         0.158   0.3700
# 444         0.655   0.4500
# 445         0.356   0.5370
# 446         0.506   0.6580
# 447         0.304   0.0465
# 448         0.693   0.4770
# 449         0.662   0.4150
# 450         0.644   0.5990
# 451         0.521   0.1350
# 452         0.490   0.4280
# 453         0.546   0.6030
# 454         0.561   0.5820
# 455         0.524   0.6050
# 456         0.406   0.2030
# 457         0.519   0.3950
# 458         0.637   0.7060
# 459         0.158   0.0397
# 460         0.814   0.5860
# 461         0.461   0.1950
# 462         0.545   0.1270
# 463         0.494   0.2870
# 464         0.702   0.2530
# 465         0.691   0.6180
# 466         0.653   0.3030
# 467         0.755   0.3800
# 468         0.567   0.3290
# 469         0.567   0.2470
# 470         0.612   0.9610
# 471         0.384   0.5670
# 472         0.482   0.0362
# 473         0.332   0.1390
# 474         0.332   0.0760
# 475         0.505   0.3810
# 476         0.509   0.0957
# 477         0.756   0.5370
# 478         0.479   0.6750
# 479         0.589   0.1510
# 480         0.554   0.6480
# 481         0.587   0.5110
# 482         0.341   0.6330
# 483         0.788   0.4890
# 484         0.235   0.1360
# 485         0.494   0.7140
# 486         0.529   0.4530
# 487         0.540   0.5520
# 488         0.583   0.3490
# 489         0.461   0.1290
# 490         0.537   0.7050
# 491         0.541   0.5550
# 492         0.288   0.2790
# 493         0.497   0.1630
# 494         0.493   0.4510
# 495         0.597   0.3810
# 496         0.451   0.4280
# 497         0.711   0.4640
# 498         0.460   0.0399
# 499         0.909   0.3390
# 500         0.702   0.8460
# 501         0.362   0.2950
# 502         0.660   0.4690
# 503         0.562   0.7510
# 504         0.528   0.1300
# 505         0.653   0.3260
# 506         0.278   0.1100
# 507         0.218   0.0395
# 508         0.686   0.8050
# 509         0.366   0.0792
# 510         0.379   0.4700
# 511         0.384   0.4270
# 512         0.671   0.6330
# 513         0.390   0.1680
# 514         0.238   0.2060
# 515         0.515   0.3510
# 516         0.412   0.1360
# 517         0.376   0.1260
# 518         0.476   0.2770
# 519         0.552   0.2200
# 520         0.758   0.8760
# 521         0.494   0.7300
# 522         0.701   0.6710
# 523         0.291   0.5130
# 524         0.525   0.9070
# 525         0.671   0.6950
# 526         0.542   0.4720
# 527         0.313   0.2360
# 528         0.517   0.0729
# 529         0.414   0.6310
# 530         0.227   0.0719
# 531         0.309   0.2700
# 532         0.443   0.1940
# 533         0.159   0.0596
# 534         0.499   0.1400
# 535         0.515   0.0732
# 536         0.421   0.1190
# 537         0.503   0.3100
# 538         0.432   0.2070
# 539         0.678   0.7790
# 540         0.531   0.7870
# 541         0.616   0.2400
# 542         0.433   0.8550
# 543         0.279   0.1440
# 544         0.194   0.1790
# 545         0.592   0.4170
# 546         0.628   0.6650
# 547         0.683   0.4200
# 548         0.642   0.5480
# 549         0.747   0.5300
# 550         0.776   0.8540
# 551         0.855   0.9160
# 552         0.446   0.5490
# 553         0.548   0.1690
# 554         0.485   0.1950
# 555         0.454   0.6290
# 556         0.457   0.7550
# 557         0.485   0.4080
# 558         0.446   0.5310
# 559         0.438   0.0776
# 560         0.581   0.3470
# 561         0.762   0.6080
# 562         0.508   0.2320
# 563         0.649   0.8080
# 564         0.407   0.4040
# 565         0.623   0.4600
# 566         0.197   0.3370
# 567         0.291   0.0804
# 568         0.669   0.3300
# 569         0.296   0.1950
# 570         0.298   0.3630
# 571         0.516   0.4590
# 572         0.551   0.2080
# 573         0.447   0.8460
# 574         0.337   0.0612
# 575         0.604   0.7930
# 576         0.494   0.7140
# 577         0.564   0.5820
# 578         0.742   0.5090
# 579         0.282   0.0379
# 580         0.769   0.5670
# 581         0.772   0.6610
# 582         0.623   0.3190
# 583         0.418   0.4500
# 584         0.310   0.0665
# 585         0.441   0.4870
# 586         0.427   0.2280
# 587         0.649   0.7650
# 588         0.385   0.0726
# 589         0.526   0.4210
# 590         0.375   0.4910
# 591         0.386   0.4560
# 592         0.706   0.1150
# 593         0.438   0.5290
# 594         0.518   0.2090
# 595         0.480   0.1800
# 596         0.170   0.0356
# 597         0.460   0.0631
# 598         0.589   0.1820
# 599         0.396   0.3240
# 600         0.430   0.0948
# 601         0.429   0.2850
# 602         0.608   0.2490
# 603         0.378   0.4690
# 604         0.923   0.6820
# 605         0.327   0.3260
# 606         0.680   0.5350
# 607         0.669   0.4170
# 608         0.412   0.1700
# 609         0.427   0.5990
# 610         0.542   0.1370
# 611         0.489   0.6030
# 612         0.642   0.4390
# 613         0.502   0.4350
# 614         0.443   0.0989
# 615         0.561   0.5690
# 616         0.495   0.5470
# 617         0.500   0.7380
# 618         0.591   0.8750
# 619         0.533   0.5520
# 620         0.701   0.6290
# 621         0.316   0.2990
# 622         0.547   0.1230
# 623         0.570   0.3690
# 624         0.795   0.5330
# 625         0.400   0.0872
# 626         0.571   0.6720
# 627         0.415   0.3040
# 628         0.294   0.1220
# 629         0.597   0.6340
# 630         0.942   0.9660
# 631         0.518   0.3870
# 632         0.470   0.2980
# 633         0.460   0.4850
# 634         0.571   0.7130
# 635         0.291   0.2170
# 636         0.649   0.5770
# 637         0.371   0.3670
# 638         0.621   0.3440
# 639         0.487   0.1230
# 640         0.557   0.5360
# 641         0.537   0.2110
# 642         0.524   0.3500
# 643         0.486   0.2300
# 644         0.785   0.5930
# 645         0.724   0.3710
# 646         0.401   0.4360
# 647         0.520   0.3620
# 648         0.600   0.7170
# 649         0.595   0.3550
# 650         0.534   0.4350
# 651         0.172   0.1120
# 652         0.313   0.3620
# 653         0.649   0.5530
# 654         0.730   0.5590
# 655         0.871   0.8860
# 656         0.477   0.1020
# 657         0.482   0.1960
# 658         0.788   0.4610
# 659         0.722   0.0903
# 660         0.616   0.5270
# 661         0.826   0.8890
# 662         0.446   0.5310
# 663         0.397   0.2620
# 664         0.139   0.0347
# 665         0.438   0.0400
# 666         0.104   0.0348
# 667         0.416   0.0979
# 668         0.217   0.0388
# 669         0.288   0.0826
# 670         0.344   0.2200
# 671         0.241   0.4510
# 672         0.523   0.8760
# 673         0.420   0.1750
# 674         0.612   0.4460
# 675         0.544   0.3670
# 676         0.747   0.4430
# 677         0.789   0.7450
# 678         0.424   0.7700
# 679         0.457   0.4170
# 680         0.481   0.3750
# 681         0.762   0.2730
# 682         0.767   0.4300
# 683         0.759   0.5560
# 684         0.456   0.4050
# 685         0.501   0.4760
# 686         0.519   0.1130
# 687         0.162   0.0972
# 688         0.342   0.0743
# 689         0.528   0.2080
# 690         0.808   0.6470
# 691         0.624   0.2830
# 692         0.697   0.4790
# 693         0.281   0.0793
# 694         0.339   0.1270
# 695         0.338   0.4000
# 696         0.295   0.1310
# 697         0.688   0.4130
# 698         0.308   0.0813
# 699         0.379   0.1460
# 700         0.508   0.1850
# 701         0.554   0.1420
# 702         0.601   0.3940
# 703         0.566   0.4910
# 704         0.666   0.5490
# 705         0.426   0.0822
# 706         0.489   0.4560
# 707         0.484   0.5100
# 708         0.563   0.1830
# 709         0.482   0.9370
# 710         0.732   0.5480
# 711         0.565   0.2170
# 712         0.652   0.1960
# 713         0.690   0.4090
# 714         0.565   0.1950
# 715         0.462   0.4760
# 716         0.695   0.7420
# 717         0.264   0.0735
# 718         0.369   0.4240
# 719         0.769   0.9470
# 720         0.533   0.9170
# 721         0.541   0.4540
# 722         0.522   0.6010
# 723         0.584   0.5880
# 724         0.381   0.1710
# 725         0.391   0.2460
# 726         0.634   0.9220
# 727         0.536   0.4300
# 728         0.656   0.3190
# 729         0.316   0.1270
# 730         0.743   0.8200
# 731         0.540   0.5330
# 732         0.774   0.8240
# 733         0.526   0.6790
# 734         0.601   0.7710
# 735         0.486   0.5490
# 736         0.214   0.3880
# 737         0.550   0.5210
# 738         0.865   0.7480
# 739         0.618   0.4590
# 740         0.592   0.1030
# 741         0.515   0.2370
# 742         0.375   0.0368
# 743         0.512   0.2550
# 744         0.396   0.2860
# 745         0.463   0.1350
# 746         0.524   0.5390
# 747         0.311   0.3870
# 748         0.561   0.1170
# 749         0.169   0.0573
# 750         0.351   0.1000
# 751         0.394   0.0387
# 752         0.613   0.5250
# 753         0.645   0.5660
# 754         0.475   0.1070
# 755         0.482   0.2890
# 756         0.682   0.5810
# 757         0.417   0.2550
# 758         0.565   0.6850
# 759         0.443   0.4740
# 760         0.242   0.0373
# 761         0.417   0.6500
# 762         0.449   0.2120
# 763         0.637   0.2960
# 764         0.458   0.5130
# 765         0.667   0.5790
# 766         0.399   0.5250
# 767         0.425   0.6500
# 768         0.346   0.2000
# 769         0.459   0.2600
# 770         0.447   0.2270
# 771         0.714   0.2970
# 772         0.550   0.3180
# 773         0.539   0.1400
# 774         0.431   0.0491
# 775         0.134   0.0435
# 776         0.501   0.8940
# 777         0.507   0.2720
# 778         0.550   0.3270
# 779         0.797   0.8360
# 780         0.618   0.4860
# 781         0.690   0.7330
# 782         0.467   0.2840
# 783         0.614   0.3900
# 784         0.550   0.7720
# 785         0.730   0.5510
# 786         0.611   0.2710
# 787         0.316   0.1090
# 788         0.517   0.3100
# 789         0.495   0.3840
# 790         0.581   0.2610
# 791         0.447   0.2830
# 792         0.553   0.7260
# 793         0.697   0.9530
# 794         0.701   0.2150
# 795         0.539   0.6650
# 796         0.488   0.7050
# 797         0.349   0.5720
# 798         0.531   0.5250
# 799         0.537   0.9720
# 800         0.473   0.2960
# 801         0.310   0.1120
# 802         0.433   0.3530
# 803         0.512   0.4320
# 804         0.734   0.8070
# 805         0.527   0.8410
# 806         0.516   0.5360
# 807         0.575   0.4810
# 808         0.463   0.6510
# 809         0.499   0.5730
# 810         0.414   0.4630
# 811         0.531   0.6840
# 812         0.666   0.8930
# 813         0.408   0.6110
# 814         0.445   0.3340
# 815         0.339   0.0360
# 816         0.560   0.0645
# 817         0.563   0.6430
# 818         0.452   0.1030
# 819         0.499   0.2770
# 820         0.367   0.1700
# 821         0.066   0.0529
# 822         0.423   0.5930
# 823         0.786   0.3060
# 824         0.282   0.6130
# 825         0.315   0.1900
# 826         0.532   0.4800
# 827         0.437   0.7330
# 828         0.359   0.2080
# 829         0.534   0.0705
# 830         0.393   0.3940
# 831         0.703   0.6890
# 832         0.412   0.2670
# 833         0.640   0.3610
# 834         0.501   0.2240
# 835         0.375   0.3400
# 836         0.518   0.0952
# 837         0.418   0.3520
# 838         0.522   0.6230
# 839         0.497   0.3380
# 840         0.482   0.1160
# 841         0.445   0.1190
# 842         0.648   0.4070
# 843         0.543   0.1590
# 844         0.425   0.1870
# 845         0.345   0.3040
# 846         0.248   0.0687
# 847         0.551   0.5270
# 848         0.359   0.1900
# 849         0.602   0.3850
# 850         0.470   0.5200
# 851         0.287   0.7070
# 852         0.707   0.9190
# 853         0.529   0.7430
# 854         0.266   0.7780
# 855         0.390   0.1320
# 856         0.428   0.0397
# 857         0.581   0.8130
# 858         0.520   0.3420
# 859         0.433   0.0363
# 860         0.773   0.3240
# 861         0.602   0.9180
# 862         0.748   0.3330
# 863         0.583   0.5500
# 864         0.478   0.4290
# 865         0.164   0.0346
# 866         0.700   0.1970
# 867         0.499   0.8750
# 868         0.515   0.1040
# 869         0.534   0.2250
# 870         0.392   0.1510
# 871         0.480   0.5500
# 872         0.557   0.2130
# 873         0.444   0.2780
# 874         0.577   0.2550
# 875         0.663   0.5240
# 876         0.557   0.6150
# 877         0.485   0.1190
# 878         0.518   0.6720
# 879         0.330   0.6250
# 880         0.396   0.3430
# 881         0.704   0.7170
# 882         0.394   0.1880
# 883         0.637   0.2750
# 884         0.646   0.4530
# 885         0.435   0.6610
# 886         0.536   0.4820
# 887         0.554   0.6810
# 888         0.424   0.1280
# 889         0.261   0.1640
# 890         0.296   0.0550
# 891         0.669   0.7390
# 892         0.704   0.9230
# 893         0.308   0.0870
# 894         0.397   0.2470
# 895         0.764   0.6960
# 896         0.740   0.4680
# 897         0.310   0.4540
# 898         0.284   0.1210
# 899         0.512   0.2150
# 900         0.482   0.2020
# 901         0.401   0.4360
# 902         0.602   0.3100
# 903         0.456   0.3540
# 904         0.207   0.0558
# 905         0.319   0.0966
# 906         0.645   0.9210
# 907         0.569   0.2050
# 908         0.614   0.6130
# 909         0.614   0.3290
# 910         0.684   0.5810
# 911         0.502   0.3160
# 912         0.468   0.4000
# 913         0.505   0.0393
# 914         0.691   0.6810
# 915         0.615   0.4290
# 916         0.708   0.6370
# 917         0.480   0.1030
# 918         0.466   0.2630
# 919         0.536   0.2610
# 920         0.561   0.6830
# 921         0.616   0.3760
# 922         0.559   0.3440

# %%
#Estrarre una canzone casuale
rand_song = random. randint(0,len(tracks_df)-1)
rand_song_df = tracks_df.head(rand_song)[-1:]
rand_song_df
# Out:
#                          id     name    artists  popularity  acousticness  \
# 321  2VxeLyX666F8uXCJ0dZF8B  Shallow  Lady Gaga          85         0.371
#
#      speechiness key  liveness  instrumentalness  energy   tempo  loudness  \
# 321       0.0308   7     0.231               0.0   0.385  95.799    -6.362
#
#      danceability  valence
# 321         0.572    0.323

# %%
spark_songs
spark_songs = spark_songs.drop('order_id', 'mode', 'release_date', 'id_artists','time_signature', 'duration_ms','timestamp')

df_sp = spark.createDataFrame(rand_song_df)
df = spark_songs.union(df_sp)

# %%
#Feature Engineering

from pyspark.ml.feature import VectorAssembler
vettore=VectorAssembler(inputCols=[
 'danceability',
 'energy',
 'loudness',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo'], outputCol='song_features')
assembled=vettore.setHandleInvalid("skip").transform(df)

from pyspark.ml.feature import StandardScaler
std=StandardScaler(inputCol='song_features',outputCol='standardized')
scale=std.fit(assembled)
df=scale.transform(assembled)

# %%
#Clustering 

from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
silhouette=[]
cls_ev = ClusteringEvaluator(predictionCol='prediction', featuresCol='standardized', \
                                metricName='silhouette', distanceMeasure='squaredEuclidean')


KMeans_algo=KMeans(featuresCol='standardized', k=3)
    
KMeans_fit=KMeans_algo.fit(df)
    
output_df =KMeans_fit.transform(df)

# %%
#Recommendation System

import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

class SpotifyRecommenderSystem():
    def __init__(self, data):
        self.data_ = data
    
 
    def Recomm(self, nome_canzone, amount=1):
        distances = []
        song = self.data_[(self.data_.name.str.lower() == nome_canzone.lower())].head(1).values[0]
        res_dt = self.data_[self.data_.name.str.lower() != nome_canzone.lower()]
        for i_song in tqdm(res_dt.values):
            distanza = 0
            for col in np.arange(len(res_dt.columns)):
                if not col in [0,1,2,14]:
                    distanza = distanza + np.absolute(float(song[col]) - float(i_song[col]))
            distances.append(distanza)
        res_dt['distance'] = distances
        res_dt = res_dt.sort_values('distance')
        columns = ['id','name', 'artists', 'acousticness', 'liveness', 'instrumentalness', 'energy', 'danceability', 'valence']
        return res_dt[columns][:amount]

# %%
datalabel = output_df.select('id',
 'name',
 'artists',
 'danceability',
 'energy',
 'key',
 'loudness',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'prediction')



final_data = datalabel.toPandas()
final_data.drop(final_data[final_data['artists'] == '0'].index, inplace = True)
final_data.drop_duplicates(inplace=True)
final_data.drop(final_data[final_data['danceability'] == 0.0000].index, inplace = True)
final_data.drop(final_data[final_data['liveness'] == 0.000].index, inplace = True)
final_data.drop(final_data[final_data['instrumentalness'] == 0.000000].index, inplace = True)
final_data.drop(final_data[final_data['energy'] == 0.0000].index, inplace = True)
final_data.drop(final_data[final_data['danceability'] == 0.000].index, inplace = True)
final_data.drop(final_data[final_data['valence'] == 0.000].index, inplace = True)

z = final_data
value_pred = final_data.iloc[-1:]['prediction']

recommendation = SpotifyRecommenderSystem(final_data)
x = rand_song_df['name'].tolist()[0]

emergify = recommendation.Recomm(x, 10)

y = rand_song_df[['id','name', 'artists',  'acousticness', 'liveness', 'instrumentalness', 'energy', 
       'danceability', 'valence']]

emergify = pd.concat([emergify, y])
emergify.to_csv('emergify.csv')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 945/945 [00:00<00:00, 12769.84it/s]

# %%
df_emergify = (spark.read.format("csv").options(header="true")
    .load("emergify.csv"))
df_emergify.show()
# Out:
# +----+--------------------+--------------------+-------------------+------------+--------+----------------+------+------------+-------+
# | _c0|                  id|                name|            artists|acousticness|liveness|instrumentalness|energy|danceability|valence|
# +----+--------------------+--------------------+-------------------+------------+--------+----------------+------+------------+-------+
# | 964|7khpPruHJK39VTBUQ...|            Stranger|         MildOrange|       0.412|   0.109|           0.113| 0.491|       0.334|  0.452|
# | 927|66JegFJ408S5Q3psO...|         Schillerize|TonioGeugelinMoglii|       0.638|   0.329|        3.79e-06| 0.468|       0.714|  0.265|
# |1015|1fbkVi5aq24ZWFUfb...|Needs (feat. Mac ...|  ZachBerroMacAyres|       0.514|  0.0672|         0.00237| 0.269|       0.638|   0.15|
# |1001|0Via7nKS0iUZug2YX...|      Still No Plans|    ThebandcalledOh|       0.272|   0.663|         2.6e-05| 0.638|       0.617|  0.792|
# | 871|7mRKpGZRtQuqgyuEl...|       Let's Pretend|               Indy|         0.3|  0.0904|        1.56e-06| 0.518|       0.694|  0.579|
# | 366|6q44hsVA6PwiK9dB5...|      Circle of Life|           LunarRAE|      0.0168|   0.166|        0.000178| 0.668|        0.56|  0.553|
# | 385|4lmfNioABw1mUpk0V...|  Offline Migrations|               Saad|       0.672|    0.15|           0.823|0.0895|       0.175| 0.0301|
# | 146|09jCT85eBB11e1BgM...|              Venice|    extremelybadman|       0.413|   0.679|         0.00648| 0.663|        0.53|  0.631|
# | 902|3ZeWiTfWUuubRzCBv...|           Bye & Bye|     UnderwaterBoys|     0.00596|   0.134|        0.000177| 0.518|       0.505|  0.418|
# |  59|18IhEejAIQxZvnjk9...|            Caroline|         RaisedonTV|      0.0236|   0.147|          0.0117| 0.908|       0.405|  0.409|
# | 321|2VxeLyX666F8uXCJ0...|             Shallow|          Lady Gaga|       0.371|   0.231|             0.0| 0.385|       0.572|  0.323|
# +----+--------------------+--------------------+-------------------+------------+--------+----------------+------+------------+-------+
